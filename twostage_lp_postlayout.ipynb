# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"
filename = "twostage_lp_layout_ac.csv"
data = pd.read_csv(os.path.join(dir, filename))

# set theme and figure size
fig, ax1 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

freq = data["DM Phase Plot X"]
mag = data["cl gain Y"]
phase = data["cl phase Y"]
titles = ["$OL Gain$", "OL Phase"]

lns1 = ax1.semilogx(freq, mag, linewidth = 2, color="black", label="Magnitude [dB]")
ax1_2  = ax1.twinx()
lns2 = ax1_2.semilogx(freq, phase, linewidth = 2, linestyle='--', color="black", label="Phase [deg]")

lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc="lower left", prop=legend_properties)

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax1.grid(linestyle='dotted')
ax1.set_xlabel('Frequency [Hz]')
ax1.set_ylabel('Magnitude [dB]')
ax1_2.set_ylabel('Phase [deg]')

ax1.set_box_aspect(1)
ax1.set_xlim(1, 1e8)
#ax1.set_ylim(-30, 110)
#ax1_2.set_ylim(-250, 60)
fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')
ax1.set_xticks(generate_log_scale(9))

filename = "twostage_lp_layout_ac_cl.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_cl.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"
filename = "twostage_lp_layout_ac.csv"
data = pd.read_csv(os.path.join(dir, filename))

# set theme and figure size
fig, ax1 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

freq = data["DM Phase Plot X"]
mag = data["DM Gain Plot Y"]
phase = data["DM Phase Plot Y"]
titles = ["$OL Gain$", "OL Phase"]

lns1 = ax1.semilogx(freq, mag, linewidth = 2, color="black", label="Magnitude [dB]")
ax1_2  = ax1.twinx()
lns2 = ax1_2.semilogx(freq, phase, linewidth = 2, linestyle='--', color="black", label="Phase [deg]")

lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc="lower left", prop=legend_properties)

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax1.set_box_aspect(1)
ax1.grid(linestyle='dotted')
ax1.set_xlabel('Frequency [Hz]')
ax1.set_ylabel('Magnitude [dB]')
ax1_2.set_ylabel('Phase [deg]')

ax1.set_xlim(1, 1e8)
ax1.set_ylim(-60, 130)
ax1_2.set_ylim(-360, 15)
fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')
ax1.set_xticks(generate_log_scale(9))

filename = "twostage_lp_layout_ac_ol.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_ol.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"

# set theme and figure size
fig, ax2 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

filename = "twostage_lp_layout_loop.csv"
data2 = pd.read_csv(os.path.join(dir, filename))
freq = data2["Loop Gain Phase X"]
loop_gain = data2["Loop Gain dB20 Y"]
loop_phase = data2["Loop Gain Phase Y"]

lns3 = ax2.semilogx(freq, loop_gain, linewidth = 2, color="black", label="Magnitude [dB]")
ax2_2  = ax2.twinx()
lns4 = ax2_2.semilogx(freq, loop_phase, linewidth = 2, linestyle='--', color="black", label="Phase [deg]")

lns_leg_2 = lns3 + lns4
labs = [l.get_label() for l in lns_leg_2]
ax2.legend(lns_leg_2, labs, loc="lower left", prop=legend_properties)

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax2.set_xlim(1, 1e7)
ax2.set_box_aspect(1)
ax2.grid(linestyle='dotted')
ax2.grid(linestyle='dotted')
ax2.set_xlabel('Frequency [Hz]')
ax2.set_ylabel('Magnitude [dB]')
ax2_2.set_ylabel('Phase [deg]')
ax2.set_xticks(generate_log_scale(9))

fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')

filename = "twostage_lp_layout_ac_loop.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_loop.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"

# set theme and figure size
fig, ax2 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

filename = "twostage_tran.csv"
data = pd.read_csv(os.path.join(dir, filename))
t = data["pulse_out X"]
pulse_out = data["pulse_out Y"]
pulse_in = data["pulse_in Y"]

lns4 = ax2.plot(t, pulse_out, linewidth = 2, color="black", label="Response")
ax2_2  = ax2.twinx()
lns3 = ax2_2.plot(t, (pulse_in-0.6)*1000+600, linewidth = 2, color="black", label="Step",linestyle='--', alpha=0.6)

lns_leg_2 = lns3 + lns4
labs = [l.get_label() for l in lns_leg_2]
ax2.legend(lns_leg_2, labs, loc="lower left", prop=legend_properties)

ax2.set_box_aspect(1)
ax2.set_xlim(0.5e-5, 0.25e-4)
ax2.grid(linestyle='dotted')
ax2.set_xlabel('Time [s]')
ax2.set_ylabel('Response Voltage [V]')
ax2_2.set_ylim(583, 614)
ax2.set_ylim(0.25, 0.9)
ax2_2.set_ylabel('Step Voltage [mV]')

fig.tight_layout()

filename = "twostage_lp_pulse.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_pulse.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl
from scipy import integrate

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"
filename = "twostage_lp_layout_noise.csv"
data = pd.read_csv(os.path.join(dir, filename))

# set theme and figure size
fig, ax1 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

freq = data["input noise; V**2 / Hz X"][:200]
noise = data["input noise; V**2 / Hz Y"][:200]

lns1 = ax1.semilogx(freq, noise, linewidth = 2, color="black", label="Noise")
ax1_1 = ax1.twinx()
ax1_1.ticklabel_format(axis='y', style='sci', scilimits=(0, 0)) 
noise_int = np.sqrt(integrate.cumulative_trapezoid(noise, freq, initial=0))
lns2 = ax1_1.semilogx(freq, noise_int, linewidth = 2, color="black", label="$\int$Noise rms", linestyle='--')

lns_leg_2 = lns1 + lns2
labs = [l.get_label() for l in lns_leg_2]
ax1.legend(lns, labs, loc=(0.42, 0.77), prop=legend_properties)

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax1.grid(linestyle='dotted')
ax1.set_xlabel('Frequency [Hz]')
ax1.set_ylabel('Noise [$V^2/Hz$]')
ax1_1.set_ylabel('$\int$ Noise rms [$V/ \sqrt{Hz}$]')

ax1.set_box_aspect(1)
ax1.set_xlim(1, 1e4)
ax2.set_xlim(1, 1e4)
fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')
ax1.set_xticks(generate_log_scale(5))
ax2.set_xticks(generate_log_scale(5))

filename = "twostage_lp_layout_noise.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# <>:31: SyntaxWarning: invalid escape sequence '\i'
# <>:46: SyntaxWarning: invalid escape sequence '\i'
# <>:31: SyntaxWarning: invalid escape sequence '\i'
# <>:46: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\techu\AppData\Local\Temp\ipykernel_10840\3067173326.py:31: SyntaxWarning: invalid escape sequence '\i'
#   lns2 = ax1_1.semilogx(freq, noise_int, linewidth = 2, color="black", label="$\int$Noise rms", linestyle='--')
# C:\Users\techu\AppData\Local\Temp\ipykernel_10840\3067173326.py:46: SyntaxWarning: invalid escape sequence '\i'
#   ax1_1.set_ylabel('$\int$ Noise rms [$V/ \sqrt{Hz}$]')
# Saving to ../report/imgs\twostage_lp_layout_noise.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"

# set theme and figure size
fig, ax2 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

filename = "twostage_lp_layout_ac.csv"
data2 = pd.read_csv(os.path.join(dir, filename))
freq = data2["CMRR Plot X"]
cmrr = data2["CMRR Plot Y"]
psr = (-1)*(data2["psr Y"]-data2["cl gain Y"])

ax2.semilogx(freq, cmrr, linewidth = 2, color="black", label="CMRR")
ax2.semilogx(freq, psr, linewidth = 2, linestyle='--', color="black", label="PSRR")

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax2.set_xlim(1, 1e8)
ax2.set_box_aspect(1)
ax2.legend(loc="lower left")
ax2.grid(linestyle='dotted')
ax2.set_xlabel('Frequency [Hz]')
ax2.set_ylabel('Magnitude [dB]')
ax2_2.set_ylabel('Phase [deg]')
ax2.set_xticks(generate_log_scale(9))

fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')

filename = "twostage_lp_layout_ac_cmrr_psrr.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False

if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_cmrr_psrr.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"
filename = "twostage_lp_layout_ac.csv"
data = pd.read_csv(os.path.join(dir, filename))

# set theme and figure size
fig, ax1 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

filename = "twostage_lp_layout_ac.csv"
data = pd.read_csv(os.path.join(dir, filename))
freq = data["DM Phase Plot X"]
mag = data["DM Gain Plot Y"]
phase = data["DM Phase Plot Y"]

filename = "twostage_lp_ac.csv"
data2 = pd.read_csv(os.path.join(dir, filename))
mag2 = data2["DM Gain Plot Y"]
phase2 = data2["DM Phase Plot Y"]

ax1.semilogx(freq, mag2, linewidth = 2, color="black", label="Pre-layout", alpha=0.5)
ax1.semilogx(freq, mag, linewidth = 2, linestyle='--', color="black", label="Post-layout", alpha=1)

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax1.legend(loc="lower left")
ax1.set_box_aspect(1)
ax1.grid(linestyle='dotted')
ax1.set_xlabel('Frequency [Hz]')
ax1.set_ylabel('Magnitude [dB]')
ax1_2.set_ylabel('Phase [deg]')

ax1.set_xlim(1, 1e8)
ax1.set_ylim(-60, 130)
ax1_2.set_ylim(-360, 15)
fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')
ax1.set_xticks(generate_log_scale(9))

filename = "twostage_lp_layout_ac_ol_cmp.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_ol_cmp.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"
filename = "twostage_lp_layout_ac.csv"
data = pd.read_csv(os.path.join(dir, filename))
freq = data["DM Phase Plot X"]
mag = data["DM Gain Plot Y"]
phase = data["DM Phase Plot Y"]

filename = "twostage_lp_ac.csv"
data2 = pd.read_csv(os.path.join(dir, filename))
mag2 = data2["DM Gain Plot Y"]
phase2 = data2["DM Phase Plot Y"]
data = pd.read_csv(os.path.join(dir, filename))

# set theme and figure size
fig, ax1 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)



ax1.semilogx(freq, phase2, linewidth = 2, color="black", label="Pre-layout", alpha=0.5)
ax1.semilogx(freq, phase, linewidth = 2, linestyle='--', color="black", label="Post-layout", alpha=1)

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax1.legend(loc="lower left")
ax1.set_box_aspect(1)
ax1.grid(linestyle='dotted')
ax1.set_xlabel('Frequency [Hz]')
ax1.set_ylabel('Magnitude [dB]')
ax1_2.set_ylabel('Phase [deg]')

ax1.set_xlim(1, 1e8)
ax1.set_ylim(-360, 15)
fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')
ax1.set_xticks(generate_log_scale(9))

filename = "twostage_lp_layout_ac_ol_phase_cmp.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_ol_phase_cmp.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"

# set theme and figure size
fig, ax2 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

filename = "twostage_lp_layout_ac.csv"
data = pd.read_csv(os.path.join(dir, filename))
cmrr = data["CMRR Plot Y"]
psr = (-1)*(data["psr Y"]-data["cl gain Y"])

filename = "twostage_lp_ac.csv"
data2 = pd.read_csv(os.path.join(dir, filename))
cmrr2 = data2["CMRR Plot Y"]
psr2 = (-1)*(data2["psr Y"]-data2["cl gain Y"])

ax2.semilogx(freq, cmrr2, linewidth = 2, color="black", label="Pre-layout",alpha=0.5)
ax2.semilogx(freq, cmrr, linewidth = 2, color="black", label="Post-layout", linestyle='--')

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax2.set_xlim(1, 1e8)
ax2.set_box_aspect(1)
ax2.legend(loc="lower left")
ax2.grid(linestyle='dotted')
ax2.set_xlabel('Frequency [Hz]')
ax2.set_ylabel('Magnitude [dB]')
ax2.set_xticks(generate_log_scale(9))

fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')

filename = "twostage_lp_layout_ac_cmrr_cmp.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False

if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_cmrr_cmp.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"

# set theme and figure size
fig, ax2 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

filename = "twostage_lp_layout_ac.csv"
data = pd.read_csv(os.path.join(dir, filename))
freq = data["CMRR Plot X"]
cmrr = data["CMRR Plot Y"]
psr = (-1)*(data["psr Y"]-data["cl gain Y"])

filename = "twostage_lp_ac.csv"
data2 = pd.read_csv(os.path.join(dir, filename))
cmrr2 = data2["CMRR Plot Y"]
psr2 = (-1)*(data2["psr Y"]-data2["cl gain Y"])

ax2.semilogx(freq, psr2, linewidth = 2, color="black", label="Pre-layout",alpha=0.5)
ax2.semilogx(freq, psr, linewidth = 2, color="black", label="Post-layout", linestyle='--')

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax2.set_xlim(1, 1e8)
ax2.set_box_aspect(1)
ax2.legend(loc="lower left")
ax2.grid(linestyle='dotted')
ax2.set_xlabel('Frequency [Hz]')
ax2.set_ylabel('Magnitude [dB]')
ax2.set_xticks(generate_log_scale(9))

fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')

filename = "twostage_lp_layout_ac_psrr_cmp.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False

if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# Saving to ../report/imgs\twostage_lp_layout_ac_psrr_cmp.pdf

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib as mpl
from scipy import integrate

# Border width
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams['font.weight'] = 'regular'
legend_properties = {'weight':'regular'}
mpl.rcParams['font.size'] = 11

dir = "report_data"
filename = "twostage_lp_layout_noise.csv"
data = pd.read_csv(os.path.join(dir, filename))

# set theme and figure size
fig, ax1 = plt.subplots()
fig.set_size_inches(5, 4)
# fig.set_dpi(100)

freq = data["input noise; V**2 / Hz X"][:200]
noise = data["input noise; V**2 / Hz Y"][:200]

filename = "twostage_lp_layout_noise.csv"
data = pd.read_csv(os.path.join(dir, filename))
freq = data["input noise; V**2 / Hz X"][:200]
noise = data["input noise; V**2 / Hz Y"][:200]

filename = "twostage_lp_noise.csv"
data2 = pd.read_csv(os.path.join(dir, filename))
freq = data2["input noise; V**2 / Hz X"][:200]
noise2 = data2["input noise; V**2 / Hz Y"][:200]

noise_int = np.sqrt(integrate.cumulative_trapezoid(noise, freq, initial=0))
noise_int2 = np.sqrt(integrate.cumulative_trapezoid(noise2, freq, initial=0))
ax1.semilogx(freq, noise_int, linewidth = 2, color="black", label="$\int$Noise rms", linestyle='--')
ax1.semilogx(freq, noise_int2, linewidth = 2, color="black", label="$\int$Noise rms", linestyle='--')

def generate_log_scale(decades):
    scale = []
    for i in range(0, decades):
        scale.append(10**i)
    return scale

ax1.legend()
ax1.grid(linestyle='dotted')
ax1.set_xlabel('Frequency [Hz]')
ax1.set_ylabel('Noise [$V^2/Hz$]')
ax1_1.set_ylabel('$\int$ Noise rms [$V/ \sqrt{Hz}$]')

ax1.set_box_aspect(1)
ax1.set_xlim(1, 1e4)
ax2.set_xlim(1, 1e4)
fig.tight_layout()
# plt.title('Three Mirror OTA AC Analysis')
ax1.set_xticks(generate_log_scale(5))
ax2.set_xticks(generate_log_scale(5))

filename = "twostage_lp_layout_noise.pdf"
path = os.path.join("../report/imgs", filename)
overwrite = False
if not os.path.isfile(path) or overwrite:
    print("Saving to", path)
    plt.savefig(path)
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\i'
# <>:40: SyntaxWarning: invalid escape sequence '\i'
# <>:52: SyntaxWarning: invalid escape sequence '\i'
# <>:39: SyntaxWarning: invalid escape sequence '\i'
# <>:40: SyntaxWarning: invalid escape sequence '\i'
# <>:52: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\techu\AppData\Local\Temp\ipykernel_10840\37154867.py:39: SyntaxWarning: invalid escape sequence '\i'
#   ax1.semilogx(freq, noise_int, linewidth = 2, color="black", label="$\int$Noise rms", linestyle='--')
# C:\Users\techu\AppData\Local\Temp\ipykernel_10840\37154867.py:40: SyntaxWarning: invalid escape sequence '\i'
#   ax1.semilogx(freq, noise_int2, linewidth = 2, color="black", label="$\int$Noise rms", linestyle='--')
# C:\Users\techu\AppData\Local\Temp\ipykernel_10840\37154867.py:52: SyntaxWarning: invalid escape sequence '\i'
#   ax1_1.set_ylabel('$\int$ Noise rms [$V/ \sqrt{Hz}$]')
