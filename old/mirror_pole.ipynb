# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from _handledata import DataHandler
from _plot import Plot

# %%
reader = DataHandler()
mos = Plot()

reader.load("nch_25")

id = 1.4e-6
gateL = 8
vdsrc = 0.3
fp = 0.1e6
mos.setgateL(gateL)
mos.setvdsrc(vdsrc)
gmid_arr    = reader.get_axis("gmoverid", mos.getvdsrc(), mos.getgateL())
ft_arr      = reader.get_axis("ft", mos.getvdsrc(), mos.getgateL())
idw_arr     = reader.get_axis("id/w", mos.getvdsrc(), mos.getgateL())

vals = {
    "gmid": [],
    "pole": [],
    "w": []
}
for gmid in range(5, 26):
    gm = gmid * id
    for i in range(0, len(gmid_arr)):
        if gmid_arr[i] < gmid:
            gmid_true = gmid_arr[i]
            ft = ft_arr[i]
            idw = idw_arr[i]
            break
    cgg = 2*(gm / (2*np.pi*ft))
    pole = gm / (2*np.pi*cgg)
    w = id / idw
    vals["gmid"].append(gmid_true)
    vals["pole"].append("{:.2e}".format(float(pole)))
    vals["w"].append("{:.2e}".format(float(w)))

latex = True
if not latex:
    for j in vals["pole"]:
        if float(j) > fp:
            gmid = vals["gmid"][vals["pole"].index(j)]
            pole = j
            w = vals["w"][vals["pole"].index(j)]
            WL = float(w) * gateL
            print("gmid: {0}, pole: {1}, w: {2}, WL: {3}".format(gmid, pole, w, WL))
else:
    for j in vals["pole"]:
        if float(j) > fp:
            gmid = vals["gmid"][vals["pole"].index(j)]
            pole = j
            w = vals["w"][vals["pole"].index(j)]
            WL = float(w) * gateL
            print("{0} & {1} & {2} & {3} \\\\".format(gmid[0], pole, w, WL))
# Out:
# gmid: [4.82369267], pole: 1.45e+07, w: 9.62e-07, WL: 7.696e-06
# gmid: [5.87466642], pole: 1.32e+07, w: 1.33e-06, WL: 1.064e-05
# gmid: [6.85226636], pole: 1.16e+07, w: 1.80e-06, WL: 1.44e-05
# gmid: [7.71795766], pole: 1.03e+07, w: 2.34e-06, WL: 1.872e-05
# gmid: [8.73957295], pole: 8.90e+06, w: 3.14e-06, WL: 2.512e-05
# gmid: [9.95343699], pole: 7.50e+06, w: 4.39e-06, WL: 3.512e-05
# gmid: [10.88608806], pole: 6.57e+06, w: 5.64e-06, WL: 4.512e-05
# gmid: [11.92773619], pole: 5.66e+06, w: 7.41e-06, WL: 5.928e-05
# gmid: [12.49175618], pole: 5.22e+06, w: 8.58e-06, WL: 6.864e-05
# gmid: [13.70958542], pole: 4.37e+06, w: 1.17e-05, WL: 9.36e-05
# gmid: [14.36399241], pole: 3.97e+06, w: 1.39e-05, WL: 0.0001112
# gmid: [15.76158964], pole: 3.20e+06, w: 1.99e-05, WL: 0.0001592
# gmid: [16.50137767], pole: 2.84e+06, w: 2.42e-05, WL: 0.0001936
# gmid: [17.26407796], pole: 2.50e+06, w: 2.96e-05, WL: 0.0002368
# gmid: [18.83492528], pole: 1.88e+06, w: 4.57e-05, WL: 0.0003656
# gmid: [19.62715579], pole: 1.61e+06, w: 5.76e-05, WL: 0.0004608
# gmid: [20.41137211], pole: 1.36e+06, w: 7.32e-05, WL: 0.0005856
# gmid: [21.91945256], pole: 9.37e+05, w: 1.22e-04, WL: 0.000976
# gmid: [22.62993333], pole: 7.64e+05, w: 1.59e-04, WL: 0.001272
# gmid: [23.9512642], pole: 4.89e+05, w: 2.78e-04, WL: 0.002224
# gmid: [24.56379366], pole: 3.85e+05, w: 3.72e-04, WL: 0.002976
# 4.823692665772628 & 1.45e+07 & 9.62e-07 & 7.696e-06 \\
# 5.874666420379637 & 1.32e+07 & 1.33e-06 & 1.064e-05 \\
# 6.852266357782618 & 1.16e+07 & 1.80e-06 & 1.44e-05 \\
# 7.717957660226165 & 1.03e+07 & 2.34e-06 & 1.872e-05 \\
# 8.739572948742902 & 8.90e+06 & 3.14e-06 & 2.512e-05 \\
# 9.953436989309411 & 7.50e+06 & 4.39e-06 & 3.512e-05 \\
# 10.88608805972124 & 6.57e+06 & 5.64e-06 & 4.512e-05 \\
# 11.92773619351931 & 5.66e+06 & 7.41e-06 & 5.928e-05 \\
# 12.49175618381964 & 5.22e+06 & 8.58e-06 & 6.864e-05 \\
# 13.70958541882069 & 4.37e+06 & 1.17e-05 & 9.36e-05 \\
# 14.36399241414429 & 3.97e+06 & 1.39e-05 & 0.0001112 \\
# 15.76158964451974 & 3.20e+06 & 1.99e-05 & 0.0001592 \\
# 16.50137766714747 & 2.84e+06 & 2.42e-05 & 0.0001936 \\
# 17.26407795521275 & 2.50e+06 & 2.96e-05 & 0.0002368 \\
# 18.83492527942469 & 1.88e+06 & 4.57e-05 & 0.0003656 \\
# 19.62715578677883 & 1.61e+06 & 5.76e-05 & 0.0004608 \\
# 20.41137210816818 & 1.36e+06 & 7.32e-05 & 0.0005856 \\
# 21.91945256025517 & 9.37e+05 & 1.22e-04 & 0.000976 \\
# 22.62993333258426 & 7.64e+05 & 1.59e-04 & 0.001272 \\
# 23.95126420484437 & 4.89e+05 & 2.78e-04 & 0.002224 \\
# 24.56379366091372 & 3.85e+05 & 3.72e-04 & 0.002976 \\
# C:\Users\techu\AppData\Local\Temp\ipykernel_22096\167592192.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   vals["pole"].append("{:.2e}".format(float(pole)))
# C:\Users\techu\AppData\Local\Temp\ipykernel_22096\167592192.py:34: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   vals["w"].append("{:.2e}".format(float(w)))

# %%
reader = DataHandler()
mos = Plot()

reader.load("pch_25")

id = 1.4e-6
gateL = 10
vdsrc = 0.3
fp = 0.1e6
mos.setgateL(gateL)
mos.setvdsrc(vdsrc)
gmid_arr    = reader.get_axis("gmoverid", mos.getvdsrc(), mos.getgateL())
ft_arr      = reader.get_axis("ft", mos.getvdsrc(), mos.getgateL())
idw_arr     = reader.get_axis("id/w", mos.getvdsrc(), mos.getgateL())

vals = {
    "gmid": [],
    "pole": [],
    "w": []
}
for gmid in range(5, 26):
    gm = gmid * id
    for i in range(0, len(gmid_arr)):
        if gmid_arr[i] < gmid:
            gmid_true = gmid_arr[i]
            ft = ft_arr[i]
            idw = idw_arr[i]
            break
    cgg = 2*(gm / (2*np.pi*ft))
    pole = gm / (2*np.pi*cgg)
    w = id / idw
    vals["gmid"].append(gmid_true)
    vals["pole"].append("{:.2e}".format(float(pole)))
    vals["w"].append("{:.2e}".format(float(w)))

for j in vals["pole"]:
    if float(j) > fp:
        gmid = vals["gmid"][vals["pole"].index(j)]
        pole = j
        w = vals["w"][vals["pole"].index(j)]
        WL = float(w) * gateL
        print("gmid: {0}, pole: {1}, w: {2}, WL: {3}".format(gmid, pole, w, WL))
# Out:
# gmid: [4.9132764], pole: 2.87e+06, w: -4.48e-06, WL: -4.4800000000000005e-05
# gmid: [5.80350532], pole: 2.71e+06, w: -5.79e-06, WL: -5.79e-05
# gmid: [6.86510029], pole: 2.48e+06, w: -7.84e-06, WL: -7.84e-05
# gmid: [7.84655995], pole: 2.28e+06, w: -1.02e-05, WL: -0.00010200000000000001
# gmid: [8.62335762], pole: 2.13e+06, w: -1.24e-05, WL: -0.000124
# gmid: [9.51977977], pole: 1.97e+06, w: -1.55e-05, WL: -0.000155
# gmid: [10.55220661], pole: 1.80e+06, w: -1.97e-05, WL: -0.00019700000000000002
# gmid: [11.73131234], pole: 1.62e+06, w: -2.57e-05, WL: -0.000257
# gmid: [12.37629477], pole: 1.52e+06, w: -2.97e-05, WL: -0.000297
# gmid: [13.76862431], pole: 1.31e+06, w: -4.06e-05, WL: -0.000406
# gmid: [14.50824167], pole: 1.20e+06, w: -4.81e-05, WL: -0.000481
# gmid: [15.26884923], pole: 1.09e+06, w: -5.75e-05, WL: -0.000575
# gmid: [16.81879652], pole: 8.71e+05, w: -8.45e-05, WL: -0.0008449999999999999
# gmid: [17.58754613], pole: 7.63e+05, w: -1.04e-04, WL: -0.00104
# gmid: [18.33723531], pole: 6.60e+05, w: -1.29e-04, WL: -0.00129
# gmid: [19.73801571], pole: 4.75e+05, w: -2.04e-04, WL: -0.00204
# gmid: [20.96151362], pole: 3.25e+05, w: -3.32e-04, WL: -0.00332
# gmid: [21.5031813], pole: 2.64e+05, w: -4.28e-04, WL: -0.00428
# gmid: [22.92234438], pole: 1.33e+05, w: -9.53e-04, WL: -0.00953
# C:\Users\techu\AppData\Local\Temp\ipykernel_22096\1456746647.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   vals["pole"].append("{:.2e}".format(float(pole)))
# C:\Users\techu\AppData\Local\Temp\ipykernel_22096\1456746647.py:34: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   vals["w"].append("{:.2e}".format(float(w)))
